# %% [markdown]
# # Sample Notebook
#
# This is a sample Jupyter notebook for data science experiments and ML projects.

# %%
import pandas as pd

# Sample data
df = pd.DataFrame(
    {
        "name": ["Project A", "Project B", "Project C"],
        "status": ["complete", "in_progress", "planned"],
        "score": [0.95, 0.82, 0.0],
    }
)

df
